# %%
# %matplotlib inline

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestClassifier

# %%
folder_path = "c:/users/jeff/dropbox/kaggle_animal_shelter/"

# %%
train = pd.read_csv(folder_path + "train.csv", encoding='utf-8')
test = pd.read_csv(folder_path + "test.csv", encoding='utf-8')

# %%
combined = train.append(test)

# %%
combined
# Out:
#       AgeuponOutcome AnimalID AnimalType  \
# 0             1 year  A671945        Dog
# 1             1 year  A656520        Cat
# 2            2 years  A686464        Dog
# 3            3 weeks  A683430        Cat
# 4            2 years  A667013        Dog
# 5            1 month  A677334        Dog
# 6            3 weeks  A699218        Cat
# 7            3 weeks  A701489        Cat
# 8           5 months  A671784        Dog
# 9             1 year  A677747        Dog
# 10           2 years  A668402        Cat
# 11           2 years  A666320        Dog
# 12           4 years  A684601        Dog
# 13           2 years  A704702        Dog
# 14            1 year  A688584        Dog
# 15          3 months  A678825        Cat
# 16           3 weeks  A678050        Cat
# 17           2 weeks  A680028        Dog
# 18           2 years  A679010        Cat
# 19            1 year  A684787        Dog
# 20          2 months  A670658        Dog
# 21            1 year  A708812        Cat
# 22           2 years  A705262        Dog
# 23         10 months  A665781        Dog
# 24          2 months  A676333        Dog
# 25           1 month  A712750        Cat
# 26          6 months  A718832        Dog
# 27           5 years  A698777        Dog
# 28          2 months  A715348        Cat
# 29           7 years  A708666        Cat
# ...              ...      ...        ...
# 11426        5 years      NaN        Dog
# 11427       2 months      NaN        Dog
# 11428        3 years      NaN        Dog
# 11429        2 years      NaN        Dog
# 11430       2 months      NaN        Cat
# 11431        2 years      NaN        Cat
# 11432        5 years      NaN        Dog
# 11433       2 months      NaN        Cat
# 11434        6 years      NaN        Dog
# 11435        3 weeks      NaN        Cat
# 11436       5 months      NaN        Cat
# 11437       6 months      NaN        Dog
# 11438        1 month      NaN        Dog
# 11439        2 years      NaN        Dog
# 11440         1 week      NaN        Cat
# 11441        4 years      NaN        Dog
# 11442        2 years      NaN        Dog
# 11443       6 months      NaN        Cat
# 11444        2 years      NaN        Cat
# 11445        2 weeks      NaN        Cat
# 11446       2 months      NaN        Cat
# 11447         1 year      NaN        Dog
# 11448       2 months      NaN        Dog
# 11449       6 months      NaN        Dog
# 11450      10 months      NaN        Dog
# 11451       2 months      NaN        Cat
# 11452        2 weeks      NaN        Cat
# 11453         1 year      NaN        Cat
# 11454        6 years      NaN        Dog
# 11455        4 years      NaN        Dog
#
#                                       Breed                Color  \
# 0                     Shetland Sheepdog Mix          Brown/White
# 1                    Domestic Shorthair Mix          Cream Tabby
# 2                              Pit Bull Mix           Blue/White
# 3                    Domestic Shorthair Mix           Blue Cream
# 4               Lhasa Apso/Miniature Poodle                  Tan
# 5         Cairn Terrier/Chihuahua Shorthair            Black/Tan
# 6                    Domestic Shorthair Mix           Blue Tabby
# 7                    Domestic Shorthair Mix          Brown Tabby
# 8             American Pit Bull Terrier Mix            Red/White
# 9                             Cairn Terrier                White
# 10                   Domestic Shorthair Mix                Black
# 11                  Miniature Schnauzer Mix               Silver
# 12                             Pit Bull Mix                Brown
# 13                    Yorkshire Terrier Mix            Black/Red
# 14                       Great Pyrenees Mix          White/Cream
#
#       SexuponOutcome
# 0      Neutered Male
# 1      Spayed Female
# 2      Neutered Male
# 3        Intact Male
# 4      Neutered Male
# 5      Intact Female
# 6        Intact Male
# 7            Unknown
# 8      Spayed Female
# 9      Spayed Female
# 10           Unknown
# 11     Spayed Female
# 12     Neutered Male
# 13     Neutered Male
# 14     Neutered Male
# 15     Neutered Male
# 16       Intact Male
# 17     Intact Female
# 18     Intact Female
# 19     Neutered Male
# 20       Intact Male
# 21     Spayed Female
# 22     Spayed Female
# 23     Neutered Male
# 24     Neutered Male
# 25     Intact Female
# 26     Spayed Female
# 27     Spayed Female
# 28     Spayed Female
# 29     Neutered Male
# ...              ...
# 11426  Neutered Male
# 11427  Intact Female
# 11428  Neutered Male
# 11429  Spayed Female
# 11430  Spayed Female
# 11431    Intact Male
# 11432  Spayed Female
# 11433  Intact Female
# 11434  Spayed Female
# 11435    Intact Male
# 11436  Neutered Male
# 11437  Intact Female
# 11438  Neutered Male
# 11439  Spayed Female
# 11440        Unknown
# 11441  Neutered Male
# 11442  Neutered Male
# 11443  Spayed Female
# 11444  Intact Female
# 11445    Intact Male
# 11446  Neutered Male
# 11447  Spayed Female
# 11448  Spayed Female
# 11449  Spayed Female
# 11450  Neutered Male
# 11451  Neutered Male
# 11452  Intact Female
# 11453  Intact Female
# 11454  Neutered Male
# 11455    Intact Male
#
# [38185 rows x 11 columns]

# %% [markdown]
# ### Separating out sex and spay/neuter info

# %%
def cleanFeatures(df):
    df['Male'] = (df['SexuponOutcome'] == u'Intact Male') | (df['SexuponOutcome'] == u'Neutered Male')
    df['NeuteredSpayed'] = (df['SexuponOutcome'] == u'Spayed Female') | (df['SexuponOutcome'] == u'Neutered Male')
    df['SexuponOutcomeKnown'] = ~df['SexuponOutcome'].isnull()

    df = df.drop('SexuponOutcome',1)

    df['Dog'] = df['AnimalType'] == u'Dog'
    df = df.drop('AnimalType',1)

    (df['Age (Weeks)'],df['Units']) = (df['AgeuponOutcome'].str.split(' ', expand=True)[0],
                               df['AgeuponOutcome'].str.split(' ', expand=True)[1])

    df['Age (Weeks)'] = df['Age (Weeks)'].convert_objects(convert_numeric=True)

    df.loc[df['Units'] == 'years','Units'] = 'year'
    df.loc[df['Units'] == 'months','Units'] = 'month'
    df.loc[df['Units'] == 'weeks','Units'] = 'week'

    df.loc[df['Units'] == 'year','Age (Weeks)'] = df.loc[df['Units'] == 'year','Age (Weeks)'] * 52
    df.loc[df['Units'] == 'month','Age (Weeks)'] = df.loc[df['Units'] == 'month','Age (Weeks)'] * 4

    df.loc[df['Age (Weeks)'].isnull(),'Age (Weeks)'] = 0

    df = df.drop(['AgeuponOutcome','Units'],1)

    df['DateTime'] = pd.to_datetime(df['DateTime'])

    df['YearOutcome'] = df['DateTime'].dt.year
    df['MonthOutcome'] = df['DateTime'].dt.month

    df = df.drop('DateTime',1)

    df['HasName'] = ~df['Name'].isnull()

    df = df.drop('Name',axis=1)

    df['IsMix'] = df['Breed'].str.contains('Mix')

    color_list = []

    for color in df['Color'].unique():
        new_colors = color.split('/')
        for new_color in new_colors:
            new_color_list = new_color.split(' ')
            for identifier in new_color_list:
                if str(identifier) not in color_list:
                    color_list.append(str(identifier))

    for color in color_list:
        df[str(color)] = df['Color'].str.contains(color)

    df = df.drop('Color', axis=1)

    breed_list = []

    df['Mixed'] = df['Breed'].str.contains('Mix')
    df['Breed'] = df['Breed'].str.rstrip('Mix').str.rstrip()

    df['PitBull'] = df['Breed'].str.contains('Pit Bull')
    df['Terrier'] = df['Breed'].str.contains('Terrier')
    df['Mini'] = df['Breed'].str.contains('Miniature')

    df_breeds = df['Breed'].reset_index().drop('index',axis=1)
    df_breeds_counts = df_breeds['Breed'].value_counts().to_frame().rename(columns={0L: 'Frequency'})
    df_breeds_counts.insert(0, 'Name', df_breeds_counts)

    df['Corgi'] = df['Breed'].str.contains('Corgi')
    df['Retriever'] = df['Breed'].str.contains('Retriever')
    df['Hound'] = df['Breed'].str.contains('Hound')
    df['Husky'] = df['Breed'].str.contains('Husky')
    df['Beagle'] = df['Breed'].str.contains('Beagle')
    df['Chihuahua'] = df['Breed'].str.contains('Chichuahua')
    df['Bulldog'] = df['Breed'].str.contains('Bulldog')

    df['CatMixed'] = (df['Breed'].str.contains('Domestic Shorthair') |
                     df['Breed'].str.contains('Domestic Longhair') |
                     df['Breed'].str.contains('Domestic Medium Hair'))

    df = df.drop('Breed',axis=1)

    if 'OutcomeSubtype' in df.columns:
        df = df.drop('OutcomeSubtype',axis=1)

# %%
combined = cleanFeatures(combined)

# %%
combined
# Out:
#       AnimalID     ID      OutcomeType   Male NeuteredSpayed  \
# 0      A671945    NaN  Return_to_owner   True           True
# 1      A656520    NaN       Euthanasia  False           True
# 2      A686464    NaN         Adoption   True           True
# 3      A683430    NaN         Transfer   True          False
# 4      A667013    NaN         Transfer   True           True
# 5      A677334    NaN         Transfer  False          False
# 6      A699218    NaN         Transfer   True          False
# 7      A701489    NaN         Transfer  False          False
# 8      A671784    NaN         Adoption  False           True
# 9      A677747    NaN         Adoption  False           True
# 10     A668402    NaN         Transfer  False          False
# 11     A666320    NaN         Adoption  False           True
# 12     A684601    NaN         Adoption   True           True
# 13     A704702    NaN  Return_to_owner   True           True
# 14     A688584    NaN  Return_to_owner   True           True
# 15     A678825    NaN         Adoption   True           True
# 16     A678050    NaN         Transfer   True          False
# 17     A680028    NaN         Transfer  False          False
# 18     A679010    NaN         Transfer  False          False
# 19     A684787    NaN  Return_to_owner   True           True
# 20     A670658    NaN         Transfer   True          False
# 21     A708812    NaN         Transfer  False           True
# 22     A705262    NaN         Adoption  False           True
# 23     A665781    NaN         Adoption   True           True
# 24     A676333    NaN  Return_to_owner   True           True
# 25     A712750    NaN         Transfer  False          False
# 26     A718832    NaN         Adoption  False           True
# 27     A698777    NaN         Adoption  False           True
# 28     A715348    NaN         Adoption  False           True
# 29     A708666    NaN  Return_to_owner   True           True
# ...        ...    ...              ...    ...            ...
# 11426      NaN  11427              NaN   True           True
# 11427      NaN  11428              NaN  False          False
# 11428      NaN  11429              NaN   True           True
# 11429      NaN  11430              NaN  False           True
# 11430      NaN  11431              NaN  False           True
# 11431      NaN  11432              NaN   True          False
# 11432      NaN  11433              NaN  False           True
# 11433      NaN  11434              NaN  False          False
# 11434      NaN  11435              NaN  False           True
# 11435      NaN  11436              NaN   True          False
# 11436      NaN  11437              NaN   True           True
# 11437      NaN  11438              NaN  False          False
# 11438      NaN  11439              NaN   True           True
# 11439      NaN  11440              NaN  False           True
# 11440      NaN  11441              NaN  False          False
# 11441      NaN  11442              NaN   True           True
# 11442      NaN  11443              NaN   True           True
# 11443      NaN  11444              NaN  False           True
# 11444      NaN  11445              NaN  False          False
# 11445      NaN  11446              NaN   True          False
# 11446      NaN  11447              NaN   True           True
# 11447      NaN  11448              NaN  False           True
# 11448      NaN  11449              NaN  False           True
# 11449      NaN  11450              NaN  False           True
# 11450      NaN  11451              NaN   True           True
# 11451      NaN  11452              NaN   True           True
# 11452      NaN  11453              NaN  False          False
# 11453      NaN  11454              NaN  False          False
# 11454      NaN  11455              NaN   True           True
# 11455      NaN  11456              NaN   True          False
#
#       SexuponOutcomeKnown    Dog  Age (Weeks)  YearOutcome  MonthOutcome  \
# 0                    True   True           52         2014             2
# 1                    True  False           52         2013            10
# 2                    True   True          104         2015             1
# 3                    True  False            3         2014             7
# 4                    True   True          104         2013            11
# 5                    True   True            4         2014             4
# 6                    True  False            3         2015             3
# 7                    True  False            3         2015             4
# 8                    True   True           20         2014             2
# 9                    True   True           52         2014             5
# 10                   True  False          104         2013            12
# 11                   True   True          104         2013            11
# 12                   True   True          208         2016             2
# 13                   True   True          104         2015             6
# 14                   True   True           52         2015            11
# 15                   True  False           12         2014             7
# 16                   True  False            3         2014             5
# 17                   True   True            2         2014             6
# 18                   True  False          104         2014             5
# 19                   True   True           52         2014             7
# 20                   True   True            8         2014             1
# 21                   True  False           52         2015             9
# 22                   True   True          104         2015             8
# 23                   True   True           40         2013            10
# 24                   True   True            8         2014             4
# 25                   True  False            4         2015            10
# 26                   True   True           24         2016             1
# 27                   True   True          260         2015             3
# 28                   True  False            8         2015            11
# 29                   True  False          364         2015             7
# ...                   ...    ...          ...          ...           ...
# 11426                True   True          260         2013            12
# 11427                True   True            8         2013            12
# 11428                True   True          156         2013            11
# 11429                True   True          104         2014             2
# 11430                True  False            8         2014            12
# 11431                True  False          104         2015             6
# 11432                True   True          260         2014             3
# 11433                True  False            8         2015             8
# 11434                True   True          312         2015             9
# 11435                True  False            3         2015             8
# 11436                True  False           20         2014             3
# 11437                True   True           24         2014             1
# 11438                True   True            4         2015             5
# 11439                True   True          104         2014             5
# 11440                True  False            1         2015            10
# 11441                True   True          208         2015             1
# 11442                True   True          104         2015            11
# 11443                True  False           24         2014            10
# 11444                True  False          104         2014             6
# 11445                True  False            2         2015             4
# 11446                True  False            8         2015             7
# 11447                True   True           52         2014            10
# 11448                True   True            8         2014             8
# 11449                True   True           24         2015             7
# 11450                True   True           40         2015            11
# 11451                True  False            8         2014             7
# 11452                True  False            2         2014            10
# 11453                True  False           52         2014             9
# 11454                True   True          312         2015             9
# 11455                True   True          208         2014             7
#
#         ...    Terrier   Mini  Corgi Retriever  Hound  Husky Beagle Chihuahua  \
# 0       ...      False  False  False     False  False  False  False     False
# 1       ...      False  False  False     False  False  False  False     False
# 22      False    False
# 23      False    False
# 24      False    False
# 25      False     True
# 26      False    False
# 27      False    False
# 28      False     True
# 29      False    False
# ...       ...      ...
# 11426   False    False
# 11427   False    False
# 11428   False    False
# 11429   False    False
# 11430   False     True
# 11431   False     True
# 11432   False    False
# 11433   False     True
# 11434   False    False
# 11435   False     True
# 11436   False     True
# 11437   False    False
# 11438   False    False
# 11439   False    False
# 11440   False     True
# 11441   False    False
# 11442   False    False
# 11443   False     True
# 11444   False     True
# 11445   False     True
# 11446   False     True
# 11447   False    False
# 11448   False    False
# 11449   False    False
# 11450   False    False
# 11451   False     True
# 11452   False     True
# 11453   False     True
# 11454   False    False
# 11455   False    False
#
# [38185 rows x 60 columns]

# %%
train_cleaned = combined[combined['ID'].isnull()].drop('ID',axis=1)

# %%
test_cleaned = combined[combined['AnimalID'].isnull()].drop('AnimalID',axis=1)

# %% [markdown]
# ## RandomForest Implementation

# %%
train_y = train_cleaned['OutcomeType']
train_X = train_cleaned.drop(['OutcomeType','AnimalID'],axis=1)

# %%
test_X = test_cleaned.drop(['ID','OutcomeType'],axis=1)

# %%
rf = RandomForestClassifier(n_estimators=100)

# %%
rf.fit(train_X, train_y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
predictions = rf.predict_proba(test_X)

# %%
headers = ['AnimalID','Adoption','Died','Euthanasia','Return_to_owner','Transfer']

# %%
output_df = pd.DataFrame(columns=headers)

# %%
test_cleaned['ID'] = 'A' + test_cleaned['ID'].astype(str)

# %%
test_cleaned
# Out:
#              ID OutcomeType   Male NeuteredSpayed SexuponOutcomeKnown    Dog  \
# 0          A1.0         NaN  False          False                True   True
# 1          A2.0         NaN  False           True                True   True
# 2          A3.0         NaN   True           True                True  False
# 3          A4.0         NaN   True          False                True   True
# 4          A5.0         NaN   True           True                True   True
# 5          A6.0         NaN   True           True                True   True
# 6          A7.0         NaN   True           True                True  False
# 7          A8.0         NaN  False           True                True  False
# 8          A9.0         NaN  False           True                True   True
# 9         A10.0         NaN  False           True                True   True
# 10        A11.0         NaN  False           True                True   True
# 11        A12.0         NaN  False          False                True   True
# 12        A13.0         NaN  False           True                True   True
# 13        A14.0         NaN   True           True                True   True
# 14        A15.0         NaN   True           True                True   True
# 15        A16.0         NaN  False           True                True   True
# 16        A17.0         NaN   True           True                True   True
# 17        A18.0         NaN   True           True                True   True
# 18        A19.0         NaN  False           True                True  False
# 19        A20.0         NaN  False          False                True  False
# 20        A21.0         NaN  False           True                True  False
# 21        A22.0         NaN  False          False                True  False
# 22        A23.0         NaN   True           True                True   True
# 23        A24.0         NaN  False          False                True  False
# 24        A25.0         NaN  False           True                True   True
# 25        A26.0         NaN   True           True                True  False
# 26        A27.0         NaN  False           True                True  False
# 27        A28.0         NaN   True          False                True   True
# 28        A29.0         NaN   True           True                True   True
# 29        A30.0         NaN   True           True                True   True
# ...         ...         ...    ...            ...                 ...    ...
# 11426  A11427.0         NaN   True           True                True   True
# 11427  A11428.0         NaN  False          False                True   True
# 11428  A11429.0         NaN   True           True                True   True
# 11429  A11430.0         NaN  False           True                True   True
# 11430  A11431.0         NaN  False           True                True  False
# 11431  A11432.0         NaN   True          False                True  False
# 11432  A11433.0         NaN  False           True                True   True
# 11433  A11434.0         NaN  False          False                True  False
# 11434  A11435.0         NaN  False           True                True   True
# 11435  A11436.0         NaN   True          False                True  False
# 11436  A11437.0         NaN   True           True                True  False
# 11437  A11438.0         NaN  False          False                True   True
# 11438  A11439.0         NaN   True           True                True   True
# 11439  A11440.0         NaN  False           True                True   True
# 11440  A11441.0         NaN  False          False                True  False
# 11441  A11442.0         NaN   True           True                True   True
# 11442  A11443.0         NaN   True           True                True   True
# 11443  A11444.0         NaN  False           True                True  False
# 11444  A11445.0         NaN  False          False                True  False
# 11445  A11446.0         NaN   True          False                True  False
# 11446  A11447.0         NaN   True           True                True  False
# 11447  A11448.0         NaN  False           True                True   True
# 11448  A11449.0         NaN  False           True                True   True
# 11449  A11450.0         NaN  False           True                True   True
# 11450  A11451.0         NaN   True           True                True   True
# 11451  A11452.0         NaN   True           True                True  False
# 11452  A11453.0         NaN  False          False                True  False
# 11453  A11454.0         NaN  False          False                True  False
# 11454  A11455.0         NaN   True           True                True   True
# 11455  A11456.0         NaN   True          False                True   True
#
#        Age (Weeks)  YearOutcome  MonthOutcome HasName   ...    Terrier   Mini  \
# 0               40         2015            10    True   ...      False  False
# 1              104         2014             7    True   ...      False  False
# 2               52         2016             1    True   ...      False  False
# 3               16         2013            12    True   ...      False  False
# 4              104         2015             9    True   ...      False   True
# 5              156         2015             6    True   ...      False  False
# 6              676         2014             3    True   ...      False  False
# 7               24         2014             6    True   ...      False  False
# 8               12         2014            11    True   ...       True  False
# 9               52         2014             4    True   ...      False  False
# 10              20         2014             1    True   ...      False  False
# 11             104         2014             9    True   ...      False  False
# 12              24         2015             1    True   ...      False  False
# 13             104         2015             9   False   ...      False   True
# 14              52         2014             7    True   ...      False  False
# 15              16         2014             3    True   ...      False  False
# 16             260         2015             5    True   ...      False  False
# 17             156         2016             1    True   ...      False  False
# 18             156         2014             6    True   ...      False  False
# 19             208         2014             2   False   ...      False  False
# 20             104         2014            11    True   ...      False  False
# 21               3         2015             5   False   ...      False  False
# 22              52         2014             6    True   ...       True  False
# 23               1         2014             7   False   ...      False  False
# 24              52         2013            10    True   ...      False  False
# 25              52         2014            12   False   ...      False  False
# 26               8         2015             7    True   ...      False  False
# 27               8         2015             3   False   ...       True  False
# 28             156         2014            10    True   ...      False  False
# 29             104         2014             5    True   ...      False  False
# ...            ...          ...           ...     ...   ...        ...    ...
# 11426          260         2013            12    True   ...      False  False
# 11427            8         2013            12    True   ...       True  False
# 11428          156         2013            11    True   ...      False  False
# 11429          104         2014             2    True   ...      False  False
# 11430            8         2014            12   False   ...      False  False
# 11431          104         2015             6   False   ...      False  False
# 11432          260         2014             3    True   ...      False  False
# 11433            8         2015             8    True   ...      False  False
# 11434          312         2015             9    True   ...      False  False
# 11435            3         2015             8   False   ...      False  False
# 11436           20         2014             3   False   ...      False  False
# 11437           24         2014             1    True   ...      False  False
# 11438            4         2015             5   False   ...      False  False
# 11439          104         2014             5    True   ...      False  False
# 11440            1         2015            10   False   ...      False  False
# 11441          208         2015             1    True   ...      False  False
# 11442          104         2015            11    True   ...      False  False
